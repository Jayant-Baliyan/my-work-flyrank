# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 3: Structured Content Archetype Clustering
# This lane was more appealing to me because here instead of clustering in traditional way i.e. clustering on the basis of the literal meaning of the text, the clustering is done based upon its performance. This way of clustering feels more challenging to me to be specific it is more technically challenging than semantic clustering.
#
# The limitation would be that two pages having dissimilar content may end up in the  same cluster whereas two pages having same or similar content may end up in different clusters because we are clustering on the basis of behavior and not meaning.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# During working on any project via agile method my work helps the content management team to decide whether to protect, refresh, rewrite, prune, or monitor which set of pages by clustering pages having similar metrics.
# If any page gets into wrong cluster then it will lead to wrong operation on that particular page instead of the required operation. Also If the clustering changes on every rerun then the trust on my work would be very less and the output of the review team would vary every time hence reducing the efficiency and creating a drift from our target.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\jayan\OneDrive\Desktop\To transfer\Internship\my-work-flyrank-main\my-work-flyrank\data\raw\content_refresh_anonymized.csv")

# %%
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
df.isnull().sum()
# Out:
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# clicks_prev_30d               0
# sessions_prev_30d             0
# content_age_days              0
# ...

# %%
print(df["impressions_90d"].max())
print(df["impressions_90d"].min())
print(df["impressions_90d"].mean())
print(df["impressions_90d"].median())
# Out:
# 517715
# 1
# 5200.3663
# 731.0

# %%
print(df["clicks_90d"].max())
print(df["clicks_90d"].min())
print(df["clicks_90d"].mean())
print(df["clicks_90d"].median())
# Out:
# 4178
# 0
# 16.097333333333335
# 1.0

# %%
print(df["pageviews_90d"].max())
print(df["pageviews_90d"].min())
print(df["pageviews_90d"].mean())
print(df["pageviews_90d"].median())
# Out:
# 5998
# 0
# 49.94246666666667
# 8.0

# %% [markdown]
# Clearly from above we can see that impressions_90d have the most widespread data.
# The difference between mean and median clearly indicates that most values are less than then the mean value. Also from min and max value we can infer that distinct groups do exist and clustering is worth finding.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My clusters show pages that receive similar response from the consumer and visitors based on various metrices.
# But these clusters produced need not be the best one as better clusters may exist for someother run. Also these clusters donot come up with a reason why that particular pages fall into that cluster only and not any other else.
# I will never claim how ranking algorithm of any search engine works or in anyway my way of clustering beats it.
# I will never claim that within a cluster one factor leads to another only that they are co-occuring.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
