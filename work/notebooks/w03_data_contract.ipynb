# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\jayan\OneDrive\Desktop\To transfer\Internship\my-work-flyrank-main\my-work-flyrank\data\raw\content_refresh_anonymized.csv")

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
df[["impressions_90d", "clicks_90d", "sessions_90d", "days_since_last_update"]]
# Out:
#        impressions_90d  clicks_90d  sessions_90d  days_since_last_update
# 0                 3803          29            17                      20
# 1                15320           7             9                      25
# 2                12581          11            11                      20
# 3                11751          58            78                      22
# 4                19140          24           145                      14
# ...                ...         ...           ...                     ...
# 29995                1           0             3                      20
# 29996              761           3             3                      20
# 29997             6336          12            44                      20
# 29998           154763         340           463                      22
# 29999             4234          80           152                     104
#
# [30000 rows x 4 columns]

# %%
df.columns.tolist()
# Out:
# ['content_id',
#  'client_id',
#  'search_volume',
#  'competition',
#  'competition_level',
#  'cpc',
#  'content_type',
#  'main_intent',
#  'word_count',
#  'char_count',
#  'provider_used',
#  'model_used',
#  'impressions_90d',
#  'clicks_90d',
#  'pageviews_90d',
#  'sessions_90d',
#  'users_90d',
#  'engaged_sessions_90d',
#  'ai_sessions_90d',
#  'scroll_events_90d',
#  'days_with_impressions',
#  'days_with_sessions',
#  'impressions_last_30d',
#  'clicks_last_30d',
#  'sessions_last_30d',
#  'impressions_prev_30d',
#  'clicks_prev_30d',
#  'sessions_prev_30d',
#  'content_age_days',
#  'age_tier',
#  'age_tier_order',
#  'days_since_last_update',
#  'freshness_tier',
#  'word_count_tier',
#  'char_count_tier',
#  'ctr',
#  'avg_position',
#  'engagement_rate',
#  'scroll_rate',
#  'ai_traffic_pct',
#  'impression_tier',
#  'position_tier',
#  'trend_direction',
#  'trend_pct']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 44 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   content_id              30000 non-null  object
#  1   client_id               30000 non-null  object
#  2   search_volume           27532 non-null  float64
#  3   competition             27532 non-null  float64
#  4   competition_level       27390 non-null  object
#  5   cpc                     27532 non-null  float64
#  6   content_type            30000 non-null  object
#  7   main_intent             27626 non-null  object
#  8   word_count              22301 non-null  float64
#  9   char_count              22301 non-null  float64
#  10  provider_used           8562 non-null   object
#  11  model_used              24267 non-null  object
#  12  impressions_90d         30000 non-null  int64
#  13  clicks_90d              30000 non-null  int64
# ...

# %%
df["content_id"].is_unique
# Out:
# True

# %% [markdown]
# Here in this dataset one row represent one page and metrices related to it.
# The 90d columns cover a 90-day window ending at the day when the details were recorded, but since there's no daye column, this window is relative rather than tied to a specific calendar date.
# Also above we have confirmed that column content_is is unique and no datetime column exist in our dataset.

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# Feature bucket - `impressions_90d`, `clicks_90d`, `ctr`, `engagement_rate`, `days_since_last_update`
#
# Label - Empty
#
# Context - `content_id`, `client_id`
#
# Excluded bucket - `provider_used` , `ai_sessions_90d`, `ai_traffic_pct`, `trend_direction`, `trend_pct`

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count provider_used              model_used  impressions_90d  \
# ...

# %%
print(df["content_id"].size)
df.isnull().sum()
# Out:
# 30000
# content_id                    0
# client_id                     0
# search_volume              2468
# competition                2468
# competition_level          2610
# cpc                        2468
# content_type                  0
# main_intent                2374
# word_count                 7699
# char_count                 7699
# provider_used             21438
# model_used                 5733
# impressions_90d               0
# clicks_90d                    0
# pageviews_90d                 0
# sessions_90d                  0
# users_90d                     0
# engaged_sessions_90d          0
# ai_sessions_90d               0
# scroll_events_90d             0
# days_with_impressions         0
# days_with_sessions            0
# impressions_last_30d          0
# clicks_last_30d               0
# sessions_last_30d             0
# impressions_prev_30d          0
# clicks_prev_30d               0
# sessions_prev_30d             0
# content_age_days              0
# ...

# %%
print(df["trend_direction"].value_counts())
print(df["trend_pct"].value_counts())
print(df["ai_sessions_90d"].value_counts())
print(df["ai_traffic_pct"].value_counts())
print(df["competition"].value_counts())
# Out:
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
# trend_pct
# -100.0     1395
#  0.0        443
# -50.0       281
# -66.7       172
#  100.0      145
#            ...
#  1079.4       1
#  75.3         1
#  109.4        1
#  67.7         1
#  577.6        1
# Name: count, Length: 2712, dtype: int64
# ai_sessions_90d
# 0     28070
# 1       700
# 2       585
# 3       165
# 4       153
# 5        67
# 6        61
# 7        40
# 8        37
# 9        26
# 10       17
# 11       17
# 12       13
# 13        7
# 14        5
# 18        4
# 20        4
# 15        4
# 19        3
# 26        3
# 16        3
# 25        2
# 21        2
# 38        1
# 41        1
# 40        1
# 24        1
# 60        1
# 46        1
# 17        1
# 64        1
# 23        1
# 59        1
# 35        1
# 39        1
# Name: count, dtype: int64
# ai_traffic_pct
# 0.00      28070
# 50.00        48
# 100.00       40
# ...

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
df.groupby("content_type")["search_volume"].apply(lambda x: x.isna().mean())
# Out:
# content_type
# comparison article    0.000000
# feedly article        1.000000
# keyword article       0.013673
# Name: search_volume, dtype: float64

# %% [markdown]
# Clearly from above we can infer content_id is unique, there is no datetime data type in our data. From overall missingness counts we can clearly see that ctr and engagement_rate have no null values also by search_volume and content_type groupby we have proved structural missingness.
#
# Additionally `provider_used` shows 21438 missing values, confirming it should be excluded due to high number of missing values and `ai_sessions_90d` shows that 28070 rows have value 0 so it should also be excluded due to being extremely being sparse

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# This data can never help me in comparison of different quarters because of missing datetime column.
#
# My data type is richer for some types only. It is richer for comparison article whereas poorer for feedly article.
#
# Never tells us about the reason for the behaviour of the pages this is because of lack of article text.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
